# %% [markdown]
# <a href="https://colab.research.google.com/github/jf921021/MIS2800/blob/main/HW3_WK4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # To Complete for Credit
# 1. Fix the errors in the 10 blocks that have an error. A brief comment has been added to each one to provide guidance on what is
# missing.
# 2. Answer the questions at the end on how you fixed the errors.
# 3. Save file into GitHub and submit the GitHub link into ISMS.

# %% [markdown]
# The next six blocks provide the exact code to run to get your Colab file started to run SQLite3.

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///AdCampaigns2026.db

# %% [markdown]
#  There are bugs (mistakes) for you to find and fix in the next 10 blocks

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
# (1, 'Doritos', 'Snacks', 7000000),
# (2, 'AWS', 'Technology', 15000000),
# (3, 'Pepsi', 'Beverages', 2000000),
# (4, 'He_Gets_Us', 'Religious', 1000000),
# (5, 'Dr_Pepper', 'Beverages', 5000000),
# (6, 'IBM', 'Technology', 100000),
# (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name, brand_type
# FROM Marketing_Brands
# WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
#Block 5
# %%sql
-- Instructions: Fix the code to find the brand types that are Religious
SELECT brand_name, brand_type
FROM Marketing_Brands
WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('He_Gets_Us', 'Religious')]

# %%
#Block 6
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_budget, brand_name
FROM Marketing_Brands
WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(100000, 'IBM')]

# %%
#Block 7
# Instructins: Fix the code so that this will run SQLite3 in
# Colab without having to wrap in Python. Hint: It's Magic!
# %%sql
SELECT *
FROM Marketing_Brands
WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
#Block 9
#-- Instructions: Sort the table by brand budget in
# DESC order. Display only the brand_name and brand_budget.
# %%sql
SELECT brand_name, brand_budget
FROM Marketing_Brands
ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
#Block 10
# Using SQLite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
SELECT *
FROM Marketing_Brands
ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# Answer the Questions Below Based on the SQL Code You've Run Above

# %% [markdown]
# 1. How did you fix the error in Block #1? Answer: I added "create table"
#
# 2. How did you fix the error in Block #2? Answer: I added "INTO"
#
# 3. How did you fix the error in Block #3? Answer: I added "*"
#
# 4. How did you fix the error in Block #4? Answer: I had to add the "FROM" and "WHERE" coding.
#
# 5. How did you fix the error in Block #5? Answer: I had to add the "FROM" and "WHERE" coding.
#
# 6. How did you fix the error in Block #6? Answer: I had to add the "FROM" and "WHERE" coding.
#
# 7. How did you fix the error in Block #7? Answer: I had to add the "FROM" and "WHERE" coding. I also had to add "*".
#
# 8. How did you fix the error in Block #8? Answer: I had to add the "FROM" and "WHERE" coding.
#
# 9. How did you fix the error in Block #9? Answer: I had to add the "FROM", "WHERE", and "ORDER" coding.
#
# 10. How did you fix the error in Block #10? Answer: I had to add "%%sql", the "FROM" and "WHERE" coding. I also had to add "ORDER BY" in "ASC."
